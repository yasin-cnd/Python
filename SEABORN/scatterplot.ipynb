# %%
import seaborn as sns
import matplotlib as plt
import pandas as pd

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(tips.total_bill,tips.tip)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="day")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="day", style="time")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
#legend

# %%
sns.set_style("white")

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",style="sex",
                color="c",
               legend=True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",style="sex",
                color="c",
               legend=False)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# palette =   deep , tab10 , hls ,  husl , Set2 , rocket ,  mako ,
#crest , viridis , dark:salmon_r , coolwarm

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="size",
                palette="coolwarm")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="tip", size="tip",palette="hls")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
#sizes

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="size", size="size",
    sizes=(3,75))
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="size", size="size",
    sizes=(30, 300), hue_norm=(0,7) )
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="size", size="size",
    sizes=(20, 200), hue_norm=(0,15) )
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style("dark")

# %%
#legend=“auto”, “brief”, “full”,

# %%
markers = {"Lunch": "s", "Dinner": "X"}
sns.scatterplot(data=tips, x="total_bill", y="tip", style="time",
                markers=markers,legend="full")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
#  s

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",
                s=100)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",
                s=10)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# color

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",
                s=100,
                color=".1")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",
                s=100,
                color=".75")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# marker

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",
                s=100,
                color=".25",
                marker="+")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",
                s=50,
                color=".3",
                marker="s")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
#edgecolor

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",
                s=150,
                color=".5",
                marker="*",
                edgecolor="c")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",
                s=150,
                color=".5",
                marker="*",
                edgecolor="violet")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
#alpha

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",
                s=150,
                color=".5",
                marker="*",
                edgecolor="violet",
                alpha=.99)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",
                s=150,
                color=".5",
                marker="*",
                edgecolor="violet",
                alpha=.35)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>
