# %%
import seaborn as sns

# %%
penguins=sns.load_dataset("penguins")

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.set_style("darkgrid") # arka plan

# %%
sns.histplot(data=penguins,x="flipper_length_mm")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
penguins=sns.load_dataset("penguins")
sns.set_style("whitegrid")

# %%
sns.histplot(data=penguins,y="flipper_length_mm",color="grey")
# Out:
# <AxesSubplot:xlabel='Count', ylabel='flipper_length_mm'>

# %%
#stat count,density,probability

# %%
sns.histplot(x="bill_length_mm",data=penguins,stat="probability",color="green")
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Probability'>

# %%
sns.set_style("darkgrid")

# %%
sns.histplot(data=penguins,x="bill_length_mm",stat="count",color="green")
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.set_style("ticks")

# %%
sns.histplot(x="bill_length_mm",data=penguins,stat="density",color="brown")
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Density'>

# %%
## binwidth

# %%
sns.histplot(data=penguins,x="flipper_length_mm",binwidth=10,color="red")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins,x="flipper_length_mm",binwidth=1,color="red")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
# bins

# %%
sns.histplot(data=penguins, x="flipper_length_mm", bins=15) #bins kolon sayısı
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins, x="flipper_length_mm", bins=5)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
#kde

# %%
sns.histplot(data=penguins, x="flipper_length_mm",color="c", kde=True)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins, x="flipper_length_mm",color="c", kde=False)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
#alpha

# %%
sns.histplot(data=penguins, x="flipper_length_mm",color="plum", kde=True,alpha=0.8)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins, x="flipper_length_mm",color="plum" ,kde=True,alpha=0.2)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
#fill

# %%
sns.histplot(x="bill_length_mm",data=penguins,stat="count",fill=False,element="step")
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.histplot(x="bill_length_mm",data=penguins,stat="count",fill=True,element="step")
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Count'>

# %%
###  cumulative

# %%
sns.histplot(x="bill_length_mm",data=penguins,stat="count",element="step",cumulative=False)
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.histplot(x="bill_length_mm",data=penguins,stat="count",element="step",cumulative=True)
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(data=penguins, x="flipper_length_mm", hue="species")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
# multiple=['layer', 'stack', 'fill', 'dodge']

# %%
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", multiple="layer")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
#['bars', 'step', 'poly']

# %%
sns.histplot(penguins, x="flipper_length_mm", hue="species", element="step")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
tips = sns.load_dataset("tips")

# %%
#discrete

# %%
sns.histplot(data=tips, x="size", stat="percent",color="b" ,discrete=True)
# Out:
# <AxesSubplot:xlabel='size', ylabel='Percent'>

# %%
sns.histplot(data=tips, x="size", stat="percent",color="b", discrete=False)
# Out:
# <AxesSubplot:xlabel='size', ylabel='Percent'>

# %%
#shrink

# %%
sns.histplot(data=tips, x="day", color="c",shrink=.8)
# Out:
# <AxesSubplot:xlabel='day', ylabel='Count'>

# %%
sns.histplot(data=tips, x="day",color="c", shrink=.1)
# Out:
# <AxesSubplot:xlabel='day', ylabel='Count'>

# %%
sns.histplot(data=tips, y="day",color="c", shrink=.075)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='day'>

# %%
sns.histplot(data=tips, x="day", hue="sex", multiple="dodge", shrink=.8)
# Out:
# <AxesSubplot:xlabel='day', ylabel='Count'>

# %%
sns.histplot(data=tips, x="day", hue="sex", multiple="stack", shrink=.8)
# Out:
# <AxesSubplot:xlabel='day', ylabel='Count'>

# %%
sns.histplot(x="bill_length_mm",data=penguins,
             color="k")
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Count'>
